# %%
import joblib
import os
import librosa
import numpy as np
import pandas as pd

# Define where your project lives
BASE_PATH = r"C:\Users\Yogesh\Desktop\emotional_classification\emotion_project"

print(f"Checking for models in: {BASE_PATH}...")

try:
    # Load your trained brains (Models)
    model_mfcc = joblib.load(os.path.join(BASE_PATH, "mfcc_model.pkl"))
    model_full = joblib.load(os.path.join(BASE_PATH, "mfcc_pitch_energy_model.pkl"))
    
    # Load your preprocessing tools
    scaler = joblib.load(os.path.join(BASE_PATH, "scaler.pkl"))
    encoder = joblib.load(os.path.join(BASE_PATH, "encoder.pkl"))
    
    print("✅ All models and scalers loaded successfully!")
    
except FileNotFoundError as e:
    print(f"❌ Error: Could not find a file. {e}")
    print("Make sure you ran the 'Save' code in your previous notebook!")
# Out:
# Checking for models in: C:\Users\Yogesh\Desktop\emotional_classification\emotion_project...
# ✅ All models and scalers loaded successfully!
